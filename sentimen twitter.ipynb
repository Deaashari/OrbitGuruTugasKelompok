# %%
import tweepy
import re
from textblob import TextBlob

# %%
api_key = "0Zccf5G0PJ5Hv7H4WeD9AG6xP"
api_secret_key = "wA5zzgWMZIUzj7qbg4UYNeqjL6YiuzKjemjNle80k300iLh9y9"
access_token = "1104250246136131584-r7DJgVOLbaP9eSTi2VrvWR31aJovz0"
access_token_secret = "lSGT7xnNCn2khMog748PzVWtHj9hVlGi2rraR8PEN9LVZ"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
hasilSearch = api.search (q="jokowi", lang="id", count=100)

# %%
hasilAnalisis = []

for tweet in hasilSearch:
  tweet_properties = {}
  tweet_properties["tanggal_tweet"] = tweet.created_at
  tweet_properties["pengguna"] = tweet.user.screen_name
  tweet_properties["isi_tweet"] = tweet.text
  tweet_bersih = ''.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)"," ",tweet.text).split())
  
  analysis = TextBlob(tweet_bersih)
  try:
    analysis = analysis.translate(to="en")
  except Exception as e:
    print(e)
  
  if analysis.sentiment.polarity > 0.0:
    tweet_properties["sentiment"] = "positif"
  elif analysis.sentiment.polarity == 0.0:
    tweet_properties["sentiment"] = "netral"
  else:
    tweet_properties["sentiment"] = "negatif"

  if tweet.retweet_count > 0:
    if tweet_properties not in hasilAnalisis:
      hasilAnalisis.append(tweet_properties)
  else:
    hasilAnalisis.append(tweet_properties)
# Out:
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.
# Translation API returned the input string unchanged.

# %%
tweet_positif = [t for t in hasilAnalisis if t ["sentiment"]=="positif"]
tweet_netral = [t for t in hasilAnalisis if t ["sentiment"]=="netral"]
tweet_negatif = [t for t in hasilAnalisis if t ["sentiment"]=="negatif"]

# %%
print("hasil sentiment")
print("positif: ", len(tweet_positif), "({} %)".format(100*len(tweet_positif)/len(hasilAnalisis)))
print("netral: ", len(tweet_netral), "({} %)".format(100*len(tweet_netral)/len(hasilAnalisis)))
print("negatif: ", len(tweet_negatif), "({} %)".format(100*len(tweet_negatif)/len(hasilAnalisis)))
# Out:
# hasil sentiment
# positif:  28 (28.0 %)
# netral:  57 (57.0 %)
# negatif:  15 (15.0 %)

# %%
tweet_positif
# Out:
# [{'isi_tweet': '@kantayu Krn baru era pak jokowi semua Intel dan semua phk bekerja menelusuri uang BLBI tsb dan hrs ada legalitasny… https://t.co/32M2j8Y9Bl',
#   'pengguna': 'FDerKanzler',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 54)},
#  {'isi_tweet': 'RT @sandalista1789: "PAK JOKOWI JANGAN BANTU PETERNAK BELI JAGUNG DENGAN HARGA WAJAR"\n\nContoh poster yang tidak akan ditangkap👌',
#   'pengguna': 'chaidarbp',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 44)},
#  {'isi_tweet': '@Pancasila_Oke @jokowi Keputusan penggunaan kartu vaksin sebagai syarat dlm kegiatan masyarakat sudah melalui berba… https://t.co/bcuoA2Qc5y',
#   'pengguna': 'MustBee17',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 32)},
#  {'isi_tweet': 'RT @ChusnulCh__: Kata Demokrat: Jokowi bisa membangun karena diwarisi anggaran oleh SBY, ini ngawur.\nYg betul Jokowi bisa membangun Krn sbl…',
#   'pengguna': 'Iwantrianto6',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24,

#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 34)},
#  {'isi_tweet': '@KompasTV @jokowi Indahnya negeriku',
#   'pengguna': 'Souei69679308',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 14)},
#  {'isi_tweet': 'RT @mantriss: Pak @jokowi bantu peternak beli jagung dengan harga wajar. https://t.co/FZK0rf7Rn8',
#   'pengguna': 'qldhsk',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 53)},
#  {'isi_tweet': 'RT @sandalista1789: "PAK JOKOWI JANGAN BANTU PETERNAK BELI JAGUNG DENGAN HARGA WAJAR"\n\nContoh poster yang tidak akan ditangkap👌',
#   'pengguna': 'bramantyahy_',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 39)},
#  {'isi_tweet': 'RT @YRadianto: Cisumdawu dibangun di antaranya untuk akses cepat dan lancar menuju Bandara Kertajati (yang mangkrak di era bapaknya @AgusYu…',
#   'pengguna': 'BagindaAgungKu3',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 32)},
#  {'isi_tweet': 'RT @AprilAnjani11: Nah nih udah diingatkan sama pak presiden @jokowi lho, pandemi blm berakhir meskipun ppkm udah dilonggarkan https://t.co…',
#   'pengguna': 'BimoAngkasa1',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 19)},
#  {'isi_tweet': 'RT @YRadianto: Selamat Pagi, Indonesia.\n\nYuk kita terobos 472 meter bukit di Rancakalong Sumedang lewat terowongan karya jajaran menteri Ba…',
#   'pengguna': 'BagindaAgungKu3',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 18)},
#  {'isi_tweet': 'RT @RamliRizal: Senang intelektual2  muda mulai berani bicara  🙂👍 Bravo \n\npandangan intelektual muda pesantren/NU  Mohamad Asrori Mulky MA…',
#   'pengguna': 'PradityaBeni',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 12)},
#  {'isi_tweet': '@cnbcindonesia Mungkin ini Akibat NIK pak Jokowi bocor di sosmed???',
#   'pengguna': 'kiahaly',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 7)},
#  {'isi_tweet': "RT @OposisiCerdas: Dinilai 'Maksa' Pindah Ibu Kota Negara, Said Didu Ungkap Misi Sesungguhnya Jokowi\nhttps://t.co/9JSRC2FX14",
#   'pengguna': 'MariSan11513787',
#   'sentiment': 'positif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 5)}]

# %%
tweet_netral
# Out:
# [{'isi_tweet': 'Presiden Jokowi dan Kapolri Jenderal Polisi Drs. Listyo Sigit Prabowo, https://t.co/BS5Y8Silw4. menyapa langsung se… https://t.co/o5pulDzlIb',
#   'pengguna': 'polsekpleredpwk',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 45)},
#  {'isi_tweet': 'RT @_ZahwaSfiera: Manusia itu sesungguhnya dalam keadaan tidur, dan jika telah meninggal dunia, barulah mereka terbangun\n-Sayyidina Ali bin…',
#   'pengguna': 'arnetaag',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 38)},
#  {'isi_tweet': '@PutraWadapi Dasar dungu! Setiap org yg komen dan tdk setuju kpd pengamat atau politisi kawan Jokowi disebut buzer?… https://t.co/sbBuUgvygT',
#   'pengguna': 'ISupart',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 34)},
#  {'isi_tweet': 'RT @MakanMasak: Pak @Jokowi tau gak kalo semua ayam orang Blitar berhenti bertelur, ±30% pasokan telur nasional akan berhenti, hampir 70% p…',
#   'pengguna': 'meckyyes',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 34)},
#  {'isi_tweet': 'RT @BorneoWolf: Duuhh... jangan bertubi-tubi begitu dong Pak @jokowi \n\nMosok saban minggu meresmikan bendungan terus ?\nUdah gitu ada yang d…',
#   'pengguna': 'datuksweida',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 33)},
#  {'isi_tweet': 'RT @jokowi: Semua bendungan ini akan menjadi sumber air jaringan irigasi yang dapat dimanfaatkan oleh masyarakat, khususnya para petani, un…',
#   'pengguna': 'PEDOMAN_id',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 32)},
#  {'isi_tweet': 'RT @Mfadlan1: @YRadianto Keren ,,\n\nIni modal utama menjadi negara yg rakyat nya sejahtera.  \n\nMatorsuwon pak de @jokowi',
#   'pengguna': 'evadarma42',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 28)},
#  {'isi_tweet': 'RT @_ZahwaSfiera: Manusia itu sesungguhnya dalam keadaan tidur, dan jika telah meninggal dunia, barulah mereka terbangun\n-Sayyidina Ali bin…',
#   'pengguna': 'hcyunsukk',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 22)},
#  {'isi_tweet': 'RT @jokowi: Yang sudah diresmikan tahun ini, selain yang saya sebutkan tadi, antara lain adalah Bendungan Tukul di Pacitan, Jawa Timur, Ben…',
#   'pengguna': 'PEDOMAN_id',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 22)},
#  {'isi_tweet': 'RT @jokowi: Agatu kareba, silessurengku? Pagi ini saya ke Kab. Wajo, Sulawesi Selatan. \n\nSaya hendak meninjau kegiatan vaksinasi Covid-19 b…',
#   'pengguna': 'iloveNKRI45',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 15)},
#  {'isi_tweet': 'RT @jokowi: Sepekan terakhir, saya meresmikan tiga bendungan di setiap kunjungan kerja ke daerah. Bendungan Kuningan di Jawa Barat, Bendung…',
#   'pengguna': 'PEDOMAN_id',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 4)},
#  {'isi_tweet': 'RT @gungjax: @YRadianto @jokowi the real bapak pembangunan',
#   'pengguna': 'evadarma42',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 3)},
#  {'isi_tweet': 'RT @savicali: Presiden Jokowi harus menemui petani tsb untuk minta maaf.',
#   'pengguna': 'Dedy_solin',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 2)},
#  {'isi_tweet': 'RT @jokowi: Agatu kareba, silessurengku? Pagi ini saya ke Kab. Wajo, Sulawesi Selatan. \n\nSaya hendak meninjau kegiatan vaksinasi Covid-19 b…',
#   'pengguna': 'ed_parmadi',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 2)},
#  {'isi_tweet': 'RT @BorneoWolf: Duuhh... jangan bertubi-tubi begitu dong Pak @jokowi \n\nMosok saban minggu meresmikan bendungan terus ?\nUdah gitu ada yang d…',
#   'pengguna': '_LOVE_AG4EVER',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 53)},
#  {'isi_tweet': 'RT @PolJokesID: Petani lho, ini Petani! Beliau ngasih kritik sopan, dan ga rusuh. Ini ga malu apa pemerintah ama parlemen yang mayoritas di…',
#   'pengguna': 'yayol3',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 42)},
#  {'isi_tweet': 'RT @_ZahwaSfiera: Manusia itu sesungguhnya dalam keadaan tidur, dan jika telah meninggal dunia, barulah mereka terbangun\n-Sayyidina Ali bin…',
#   'pengguna': 'Btsbighitt_',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 39)},
#  {'isi_tweet': 'Presiden @Jokowi Minta Kredit Perbankan untuk UMKM Ditingkatkan sampai 30 Persen https://t.co/qDhf5cl2Qx https://t.co/GtiBmI6dG6',
#   'pengguna': 'siscalfianty',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 38)},
#  {'isi_tweet': '@lulukzna1 @nksthi @jokowi mesakno wong cilik ora oleh sambat 😔',
#   'pengguna': 'kudu_piye_neh',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 36)},
#  {'isi_tweet': 'RT @GumilarSpandra: @kantayu Kenapa baru " sekarang " diurus..?\nMengapa pak Dahlan bertanya seperti itu..pasti ada sesuatu yg blm diungkapk…',
#   'pengguna': 'kantayu',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23,

#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 47)},
#  {'isi_tweet': 'Ini gak kaleng2...krn pak Jokowi gak pernah kerja kaleng2\n\nBagaimana wan ? @aniesbaswedan @A_rizapatria \nCak mus… https://t.co/aeBivXF4k8',
#   'pengguna': 'Ernie_es',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 43)},
#  {'isi_tweet': 'RT @jokowi: Agatu kareba, silessurengku? Pagi ini saya ke Kab. Wajo, Sulawesi Selatan. \n\nSaya hendak meninjau kegiatan vaksinasi Covid-19 b…',
#   'pengguna': 'Dedy_solin',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 33)},
#  {'isi_tweet': '@KompasTV percaya2 aja gue, silent majoritynya Jokowi banyak.',
#   'pengguna': 'amrcnavrge',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 32)},
#  {'isi_tweet': '@Kadrun_Bangsat @DivHumas_Polri Dan ketika gue bersuara gue di anggap gila di anggap  bujjer rp di anggap xxx\nOleh… https://t.co/URN4dI07Qz',
#   'pengguna': 'Mei2Namaku',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 23)},
#  {'isi_tweet': 'Kuliah Online di Akademi Desa, Kontribusi Transmigrasi Membangun Negeri\n@jokowi \n@halimiskandarnu \n@imansyukri… https://t.co/1jevCfqAex',
#   'pengguna': 'Ryanto54848864',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 21)},
#  {'isi_tweet': 'RT @jokowi: Agatu kareba, silessurengku? Pagi ini saya ke Kab. Wajo, Sulawesi Selatan. \n\nSaya hendak meninjau kegiatan vaksinasi Covid-19 b…',
#   'pengguna': 'uyhawinarwan',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 20)},
#  {'isi_tweet': 'Presiden @jokowi dan Ibu Negara Iriana Joko Widodo tiba di Pangkalan TNI AU Sultan Hasanuddin, Kabupaten Maros, Sul… https://t.co/dqlnjwIW8K',
#   'pengguna': 'MpokMae',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 5)},
#  {'isi_tweet': 'Presiden @jokowi dan Ibu Negara Iriana Joko Widodo tiba di Pangkalan TNI AU Sultan Hasanuddin, Kabupaten Maros, Sul… https://t.co/D7YkLrj1Qj',
#   'pengguna': 'GueTionghoa',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 48)},
#  {'isi_tweet': 'Presiden Jokowi beserta Kapolri Jenderal Polisi Drs. Listyo Sigit Prabowo, https://t.co/cc1nwRSxEN. meninjau vaksin… https://t.co/nSG7qApgl6',
#   'pengguna': 'RithaTheresia93',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 47)},
#  {'isi_tweet': 'PAK JOKOWI JANGAN SELESAIKAN KASUS PEMBUNUHAN MUNIR.\n\nnambahin…. https://t.co/NWsExuEbwR',
#   'pengguna': 'elang_bagus',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 43)},
#  {'isi_tweet': 'RT @gundala2221: repot bro, klo rasa benci sudah menghujam kalbu, NALAR sdh gak main, gak beda dengan @ReflyHZ , .mau bergelar PROFESOR,DOK…',
#   'pengguna': 'JudahLion188',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 41)},
#  {'isi_tweet': 'RT @_ZahwaSfiera: Manusia itu sesungguhnya dalam keadaan tidur, dan jika telah meninggal dunia, barulah mereka terbangun\n-Sayyidina Ali bin…',
#   'pengguna': 'fluffyou_gurt',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 39)},
#  {'isi_tweet': 'Pandemi membawa efek September Meroket. Mantap Pak Jokowi, ini capaian sebuah janji 🤭 https://t.co/zwtJMZJ2Fs',
#   'pengguna': 'IpungLombok',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 37)},
#  {'isi_tweet': 'RT @kontrologika: @sandalista1789 "KAMI PETANI DAN PETERNAK MENDUKUNG PAK JOKOWI 3 PERIODE"\n\nContoh poster dan mural yang tidak akan ditang…',
#   'pengguna': 'yntktx',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 36)},
#  {'isi_tweet': 'RT @_ZahwaSfiera: Manusia itu sesungguhnya dalam keadaan tidur, dan jika telah meninggal dunia, barulah mereka terbangun\n-Sayyidina Ali bin…',
#   'pengguna': 'Anggun91144658',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 29)},
#  {'isi_tweet': 'RT @OposisiCerdas: Ketua BEM UI Ajak Kampanyekan Pesan Warga Blitar yang Digelandang karena Bentangkan Poster ke Jokowi\nhttps://t.co/rXqSq6…',
#   'pengguna': 'ElfizaEnny',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 28)},
#  {'isi_tweet': 'RT @jokowi: Agatu kareba, silessurengku? Pagi ini saya ke Kab. Wajo, Sulawesi Selatan. \n\nSaya hendak meninjau kegiatan vaksinasi Covid-19 b…',
#   'pengguna': 'Iwantrianto6',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 23)},
#  {'isi_tweet': 'Presiden @jokowi dan Ibu Negara Iriana Joko Widodo tiba di Pangkalan TNI AU Sultan Hasanuddin, Kabupaten Maros, Sul… https://t.co/FjIlkJeRPf',
#   'pengguna': 'DivaCatrii',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 23)},
#  {'isi_tweet': 'RT @OposisiCerdas: Peternak Bentangkan Spanduk ke Jokowi Ditangkap Polisi, Politikus PKB: Cukuplah 2 Periode\nhttps://t.co/Is0VVNN2qe',
#   'pengguna': 'BilalPANSEL',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 20)},
#  {'isi_tweet': 'RT @Minietweets_: APAKAH INI YANG MAMANYA KARMA?\n\nTUHAN MEMANG TAK PERNAH TIDUR.\n\nSemoga @Rockygerung_rg segera insyaf dari mendzolimi pak…',
#   'pengguna': 'Warta33661526',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 14)},
#  {'isi_tweet': 'RT @_ZahwaSfiera: Manusia itu sesungguhnya dalam keadaan tidur, dan jika telah meninggal dunia, barulah mereka terbangun\n-Sayyidina Ali bin…',
#   'pengguna': 'amdabila',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 12)},
#  {'isi_tweet': 'Presiden Jokowi dan Kapolri Jenderal Polisi Drs. Listyo Sigit Prabowo, https://t.co/cc1nwRSxEN. menyapa langsung se… https://t.co/3aZUqwdZOf',
#   'pengguna': 'RithaTheresia93',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 9)},
#  {'isi_tweet': 'Presiden Jokowi dan Kapolri Jenderal Polisi Drs. Listyo Sigit Prabowo, https://t.co/v9eoqqQTtR. menyapa langsung se… https://t.co/Uj10nVH8eF',
#   'pengguna': 'PolsekCilandak9',
#   'sentiment': 'netral',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 9)}]

# %%
tweet_negatif
# Out:
# [{'isi_tweet': '@AREAJULID Mgkn kepda.e takut diomeli pak Jokowi, \nPolisi keterlaluan sih kalo memang gtu adanya',
#   'pengguna': 'MayAiniLutfi',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 43)},
#  {'isi_tweet': 'RT @BiLLRaY2019: Pak Jokowi dan #MenkeuSMI ugal-ugalan dan bikin gaduh dimasa pandemi...\n\n-Cadangan Devisa Indonesia Cetak Rekor Tertinggi-…',
#   'pengguna': 'SumantriHardjo',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 32)},
#  {'isi_tweet': 'RT @jokowi: 10 lainnya segera diresmikan. Bendungan Paselloreng dan Karalloe di Sulsel, Bendungan Ladongi di Sultra, Bendungan Bintang Bano…',
#   'pengguna': 'PEDOMAN_id',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 27)},
#  {'isi_tweet': 'RT @__AnakKolong: PAK PRESIDEN @jokowi | \n\n@KPK_RI menyatakan 95% LHKPN "TIDAK AKURAT" &amp; 15% dari 95% menunjukkan ketidaksesuaian antara pr…',
#   'pengguna': 'TotoIsmoe',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 24, 7)},
#  {'isi_tweet': 'Terjadi di era Jokowi, dg PKI perjuangan partai berkuasa\nsemakin sadis  menghina Agama Islam  dan Nabi Muhammad SAW… https://t.co/UYGPCubXgT',
#   'pengguna': 'mhbmuhib17',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 45)},
#  {'isi_tweet': 'RT @nila_mrt: Si kebo gangga mewarisi proyek" mangkrak korban korupsi besar-besaran era si kebo.\n\nYang lain boleh di selesaikan oleh Jokowi…',
#   'pengguna': 'KWijayatmoko',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 37)},
#  {'isi_tweet': 'RT @BiLLRaY2019: Pak Jokowi dan #MenkeuSMI ugal-ugalan dan bikin gaduh dimasa pandemi...\n\n-Cadangan Devisa Indonesia Cetak Rekor Tertinggi-…',
#   'pengguna': 'Agus3til1',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 17)},
#  {'isi_tweet': 'RT @waluyoiskandar: Pa jokowi bkn presiden planga plongo, orangnya ceking, nyalinya macan hutan walopun taruhannya nyawa...krn yg di rampok…',
#   'pengguna': 'kantayu',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 10)},
#  {'isi_tweet': "Akhirnya impian kecil jaman bocah.. terwujud. I was getting little bit emotional. :') sesimpel pengen liat bapak pr… https://t.co/L2xnz9IUXV",
#   'pengguna': 'fa11en_rose',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 7)},
#  {'isi_tweet': 'RT @kompascom: Polisi hendaknya tidak berlebihan jika ada warga yang memanfaatkan kunjungan presiden untuk sampaikan aspirasi. https://t.co…',
#   'pengguna': 'Nami__Ra',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 23, 2)},
#  {'isi_tweet': 'RT @Boediantar4: Pak Jokowi berkat anda Indonesia meroket tinggi sekali. Lanjutkan!\n\nAda contoh yang lain?',
#   'pengguna': 'agra22418919',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 55)},
#  {'isi_tweet': '@sephiaseph @azzizahzizah @jokowi Mau gmn sistemnya, kl gak ada sumber pendapatan ya gagal.\nSMI memang kelas dunia..👍',
#   'pengguna': 'SanteajaS',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 43)},
#  {'isi_tweet': 'RT @__AnakKolong: PAK PRESIDEN @jokowi | \n\n@KPK_RI menyatakan 95% LHKPN "TIDAK AKURAT" &amp; 15% dari 95% menunjukkan ketidaksesuaian antara pr…',
#   'pengguna': 'Maknyus_nnn',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 28)},
#  {'isi_tweet': 'RT @BiLLRaY2019: Pak Jokowi dan #MenkeuSMI ugal-ugalan dan bikin gaduh dimasa pandemi...\n\n-Cadangan Devisa Indonesia Cetak Rekor Tertinggi-…',
#   'pengguna': 'MARV3LLL',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 22, 11)},
#  {'isi_tweet': 'RT @Mirandameno12: Bila bukan pak Jokowi\nMangkrak sudah itu proyek.\nProyek terlunta lunta tidak menentu dijaman Pepo.',
#   'pengguna': 'BagindaAgungKu3',
#   'sentiment': 'negatif',
#   'tanggal_tweet': datetime.datetime(2021, 9, 9, 4, 21, 12)}]
